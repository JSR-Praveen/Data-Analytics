# %%
pip install matplotlib seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: matplotlib in c:\users\jsr\appdata\local\programs\python\python312\lib\site-packages (3.10.0)
# Requirement already satisfied: seaborn in c:\users\jsr\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jsr\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jsr\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jsr\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jsr\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\jsr\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.2.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\jsr\appdata\roaming\python\python312\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\jsr\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jsr\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jsr\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\jsr\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jsr\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jsr\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\jsr\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
x=[1,2,5,6,8,9]
y=[10,20,44,55,34,67]
print(x,y)
# Out:
# [1, 2, 5, 6, 8, 9] [10, 20, 44, 55, 34, 67]

# %%
plt.plot(x,y)

# %%
plt.bar(x,y)
plt.xlabel("x-axis label")
plt.ylabel("y-axis label")
plt.title("Sample Bar plot")
plt.show()

# %%
import pandas as pd
# !pip install openpyxl
data = pd.read_excel("empolyee Performance  Data.xlsx")
data
# Out:
# Requirement already satisfied: openpyxl in c:\users\jsr\appdata\local\programs\python\python312\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\jsr\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (2.0.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#    Employee Name  Q1 Performance (%)  Q2 Performance (%)  Q3 Performance (%)  \
# 0          Alice                  85                  88                  90
# 1            Bob                  78                  82                  79
# 2        Charlie                  92                  91                  95
# 3          Diana                  88                  85                  89
# 4            Eve                  75                  80                  82
# 5      Prashant                   56                  89                  51
# 6         Sahbaz                  28                  45                  42
# 7       Himanshu                  49                  55                  29
# 8          Amman                  29                  59                  22
# 9         Ahamed                  21                  47                  37
# 10        Shahid                  25                  46                  57
# 11       Krishna                  53                  23                  24
# 12          Tanu                  54                  48                  40
# 13         Sahil                  48                  58                  25
# 14      Mushahid                  60                  39                  34
# 15         Rtika                  52                  51                  54
# 16          Riya                  35                  46                  48
# 17        Nadeem                  32                  51                  26
# 18       Praveen                  48                  59                  44
# 19       Zeeshan                  47                  25                  57
# 20         Divya                  55                  57                  39
# 21        Trupti                  55                  33                  57
#
#     Q4 Performance (%)
# 0                   87
# 1                   85
# 2                   94
# 3                   90
# 4                   77
# 5                   26
# 6                   41
# 7                   29
# 8                   59
# 9                   34
# 10                  42
# 11                  24
# 12                  34
# 13                  52
# 14                  60
# 15                  34
# 16                  24
# 17                  24
# 18                  37
# 19                  23
# 20                  37
# 21                  38

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee Name       22 non-null     object
#  1   Q1 Performance (%)  22 non-null     int64
#  2   Q2 Performance (%)  22 non-null     int64
#  3   Q3 Performance (%)  22 non-null     int64
#  4   Q4 Performance (%)  22 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1012.0+ bytes

# %%
mean_value = data[["Q1 Performance (%)", "Q2 Performance (%)", "Q3 Performance (%)", "Q4 Performance (%)"]].mean()
median_value = data[["Q1 Performance (%)", "Q2 Performance (%)", "Q3 Performance (%)", "Q4 Performance (%)"]].median()

# %%
print("Mean")
print(mean_value)
print()
print("Median")
print(median_value)
# Out:
# Mean
# Q1 Performance (%)    52.954545
# Q2 Performance (%)    57.136364
# Q3 Performance (%)    50.954545
# Q4 Performance (%)    47.772727
# dtype: float64
#
# Median
# Q1 Performance (%)    52.5
# Q2 Performance (%)    53.0
# Q3 Performance (%)    46.0
# Q4 Performance (%)    37.5
# dtype: float64

# %%
df_melted = data.melt(id_vars=["Employee Name"],var_name="Quarter",value_name="performance")
plt.figure(figsize=(10,6))
sns.lineplot(data=df_melted,x="Quarter",y="performance",hue="Employee Name",marker="o")
plt.title("performance Trends of Employee Across Quarters")
plt.ylabel("performance (%)")
plt.xlabel("Quarters")
plt.legend(title="Employee Name")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_melted = data.melt(id_vars=["Employee Name"],var_name="Quarter",value_name="performance")
#       2 plt.figure(figsize=(10,6))
#       3 sns.lineplot(data=df_melted,x="Quarter",y="performance",hue="Employee Name",marker="o")
#
# NameError: name 'data' is not defined
